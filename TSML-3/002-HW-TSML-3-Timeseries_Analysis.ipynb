# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Элементарные-методы-анализа-временных-рядов" data-toc-modified-id="Элементарные-методы-анализа-временных-рядов-1">Элементарные методы анализа временных рядов</a></span><ul class="toc-item"><li><span><a href="#Задание" data-toc-modified-id="Задание-1.1">Задание</a></span></li><li><span><a href="#Тест-на-стационарность" data-toc-modified-id="Тест-на-стационарность-1.2">Тест на стационарность</a></span><ul class="toc-item"><li><span><a href="#Приведем-ряд-к-стационарному" data-toc-modified-id="Приведем-ряд-к-стационарному-1.2.1">Приведем ряд к стационарному</a></span><ul class="toc-item"><li><span><a href="#Преобразования-Бокса-Кокса" data-toc-modified-id="Преобразования-Бокса-Кокса-1.2.1.1">Преобразования Бокса-Кокса</a></span></li><li><span><a href="#Дифференцирование" data-toc-modified-id="Дифференцирование-1.2.1.2">Дифференцирование</a></span></li></ul></li></ul></li><li><span><a href="#Скользящее-среднее-(MA)" data-toc-modified-id="Скользящее-среднее-(MA)-1.3">Скользящее среднее (MA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.3.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.3.0.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Взвешенное-скользящее-среднее-(WMA)" data-toc-modified-id="Взвешенное-скользящее-среднее-(WMA)-1.4">Взвешенное скользящее среднее (WMA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.4.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.4.0.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Экспоненциальное-сглаживание-(EMA)" data-toc-modified-id="Экспоненциальное-сглаживание-(EMA)-1.5">Экспоненциальное сглаживание (EMA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.5.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.5.0.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Двойное-экспоненциальное-сглаживание-(DEMA)" data-toc-modified-id="Двойное-экспоненциальное-сглаживание-(DEMA)-1.6">Двойное экспоненциальное сглаживание (DEMA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.6.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.6.0.2">Для стационарного ряда</a></span></li></ul></li><li><span><a href="#Подбор-параметров.-Кросс-валидация" data-toc-modified-id="Подбор-параметров.-Кросс-валидация-1.6.1">Подбор параметров. Кросс-валидация</a></span><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.6.1.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.6.1.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Тройное-экспоненциальное-сглаживание.-Метод-Хольта-Винтерса-(TEMA)" data-toc-modified-id="Тройное-экспоненциальное-сглаживание.-Метод-Хольта-Винтерса-(TEMA)-1.7">Тройное экспоненциальное сглаживание. Метод Хольта-Винтерса (TEMA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.7.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.7.0.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Подбор-параметров" data-toc-modified-id="Подбор-параметров-1.8">Подбор параметров</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.8.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.8.0.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Кросс-валидация." data-toc-modified-id="Кросс-валидация.-1.9">Кросс-валидация.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Для-нестационарного-ряда" data-toc-modified-id="Для-нестационарного-ряда-1.9.0.1">Для нестационарного ряда</a></span></li><li><span><a href="#Для-стационарного-ряда" data-toc-modified-id="Для-стационарного-ряда-1.9.0.2">Для стационарного ряда</a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.10">Вывод</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Тройное-экспоненциальное-сглаживание-лучше-других-моделей-приближает-ряд-и-позволяет-сделать-прогноз-на-заданный-временной-интервал." data-toc-modified-id="Тройное-экспоненциальное-сглаживание-лучше-других-моделей-приближает-ряд-и-позволяет-сделать-прогноз-на-заданный-временной-интервал.-1.10.0.1">Тройное экспоненциальное сглаживание лучше других моделей приближает ряд и позволяет сделать прогноз на заданный временной интервал.</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Элементарные методы анализа временных рядов

# %% [markdown]
# ## Задание
#
# Взять из прошлого домашнего задания ряд (в двух вариантах - стационарный и нет) и приблизить оба эти варианта моделями из класса MA. Оценить качество и прислать соображения почему была выбрана та или иная модель

# %%
import pandas as pd
import numpy as np

from statsmodels.tsa.stattools import adfuller  # Dickey-Fuller Test - проверка на стационарность временного ряда
import statsmodels.api as sm # для визуализации
import statsmodels.tsa.api as smt # для визуализации

from scipy.stats import boxcox # Box-Cox преобразование

from scipy.optimize import minimize
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import TimeSeriesSplit

import matplotlib.pyplot as plt
# Out:
# C:\Users\bauhb\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\bauhb\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
international_airline_passengers = pd.read_csv('Series/international-airline-passengers.csv')

# %%
international_airline_passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   144 non-null    object
#  1   Count   144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
international_airline_passengers.head()
# Out:
#      Month  Count
# 0  1949-01    112
# 1  1949-02    118
# 2  1949-03    132
# 3  1949-04    129
# 4  1949-05    121

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=(16, 8))
    
    plt.plot(international_airline_passengers['Count'], color='blue')
    plt.title('international_airline_passengers')

    plt.tight_layout()

# %% [markdown]
# ## Тест на стационарность

# %%
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for [key, value] in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
def tsplot(y, lags=None, figsize=(14, 8), style='bmh'):
    test_stationarity(y)
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        plt.figure(figsize=figsize)
        layout = (4, 1)
        ts_ax = plt.subplot2grid(layout, (0, 0), rowspan=2)
        acf_ax = plt.subplot2grid(layout, (2, 0))
        pacf_ax = plt.subplot2grid(layout, (3, 0))

        y.plot(ax=ts_ax, color='blue', label='Or')
        ts_ax.set_title('Original')

        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05) # acf - автокорреляция
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05) # pcf - частичная автокорреляция

        plt.tight_layout()
    return

# %%
tsplot(international_airline_passengers['Count'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# Данные теста Дикки-Фуллера (p-value = 0.991880) и графики коррелограмм не отвергают гипотезу о нестационарности временного ряда.

# %%
series_non_stationary = international_airline_passengers['Count']

# %% [markdown]
# ### Приведем ряд к стационарному

# %% [markdown]
# #### Преобразования Бокса-Кокса

# %%
# Преобразование Бокса-Кокса
series = boxcox(international_airline_passengers['Count'], 0)

# %%
# Тест на стационарность
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.717017
# p-value                          0.422367
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# Удалось убрать дисперсию, но остается тренд и сезонность. Теста Дикки-Фуллера (p-value = 0.422367, Test Statistic > Critical Value (1%)) и графики коррелограмм все еще не отвергают гипотезу о нестационарности временного ряда.

# %% [markdown]
# #### Дифференцирование

# %%
series_1 = series[1:] - series[:-1]

# %%
tsplot(series_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.717131
# p-value                          0.071121
# #Lags Used                      14.000000
# Number of Observations Used    128.000000
# Critical Value (1%)             -3.482501
# Critical Value (5%)             -2.884398
# Critical Value (10%)            -2.578960
# dtype: float64

# %%
series_2 = series_1[12:] - series_1[:-12]

# %%
tsplot(series_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.443325
# p-value                          0.000249
# #Lags Used                      12.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64

# %% [markdown]
# После преобразований: p-value = 0.000249, Test Statistic = -4.443325 < Critical Value (1%) = -3.487022. Соответственно можем отклонить H0 о нестационарности ряда с уровнем значимости менее 1%.

# %%
# Получили два ряда:

# Нестационарный
series_non_stationary = international_airline_passengers['Count']

# Стационарный
series_stationary = series_2

# %% [markdown]
# ## Скользящее среднее (MA)

# %% [markdown]
# Будущее значение переменной зависит от среднего $n$ её предыдущих значений
#
# $\hat{y}_{t} = \frac{1}{k} \displaystyle\sum^{k-1}_{n=0} y_{t-n}$
#
# В данном случае $\hat{y}_{t}$ называется скользящим средним.

# %%
def moving_average(series, n):
    if not isinstance(series, pd.Series):
        series = pd.Series(series)
    return series.rolling(n).mean()

# %% [markdown]
# #### Для нестационарного ряда

# %%
ma_1 = moving_average(series_non_stationary, 7)

# %%
len(ma_1)
# Out:
# 144

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_non_stationary, color='blue',label='original')
    plt.plot(ma_1, color='red', linewidth='4', label='Moving Average')
    plt.legend()

# %% [markdown]
# #### Для стационарного ряда

# %%
ma_2 = moving_average(series_stationary, 7)

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_stationary, color='blue',label='original')
    plt.plot(ma_2, color='red', linewidth='4', label='Moving Average')
    plt.legend()

# %% [markdown]
# ## Взвешенное скользящее среднее (WMA)

# %% [markdown]
# $\hat{y}_{t} = \displaystyle\sum^{k}_{n=1} \omega_n y_{t+1-n}$
#
# $\displaystyle\sum^{k}_{n=1} {\omega_n} = 1$
#
# Обычно, чем ближе измерение к прогнозируемому, тем больше его вес.

# %%
def weighted_moving_average(series, n, weights):
    if not isinstance(weights, np.ndarray):
        weights = np.array(weights)
    if not isinstance(series, pd.Series):
        series = pd.Series(series)
    wma = series.rolling(n).apply(lambda s: (s * weights).sum() / weights.sum(), raw=True)
    return wma

# %% [markdown]
# #### Для нестационарного ряда

# %%
wma_1 = weighted_moving_average(series_non_stationary, 7, [1,1,2,3,5,8,13])

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_non_stationary, color='blue',label='original')
    plt.plot(ma_1, color='red', linewidth='2', label='MA')
    plt.plot(wma_1, color='green', linewidth='2', label='WMA')
    plt.legend()

# %% [markdown]
# #### Для стационарного ряда

# %%
wma_2 = weighted_moving_average(series_stationary, 7, [1,1,2,3,5,8,13])

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_stationary, color='blue',label='original')
    plt.plot(ma_2, color='red', linewidth='2', label='MA')
    plt.plot(wma_2, color='green', linewidth='2', label='WMA')
    plt.legend()

# %% [markdown]
# ## Экспоненциальное сглаживание (EMA)

# %% [markdown]
# Чем дальше измерение - тем меньше вклад. Для этого используется экспоненциальное скользящее среднее:
#
# $\hat{y}_{t} = \alpha \cdot y_t + (1-\alpha) \cdot \hat y_{t-1} $
#
# Предсказанное значение - это взвешеное среднее между последним наблюдением и предыдущей историей. Легко заметить, что формула рекурсивна. Параметр $\alpha$ называется сглаживающим фактором. Он определяет, как сильно мы будем опираться на историю. Чем меньше $\alpha$, тем больше влияния оказывают предыдущие предсказанные значения, и тем сильнее сглаживается ряд.

# %%
def exponential_moving_average(series, alpha, n_preds):
    result = [series[0]]
    for n in range(1, len(series)+n_preds):
        if n >= len(series):
            result.append(alpha * result[-1] + (1 - alpha) * result[n-1])
        else:
            result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return pd.Series(result)

# %% [markdown]
# #### Для нестационарного ряда

# %%
n_preds = 12
ema_1 = exponential_moving_average(series_non_stationary, 0.3, n_preds)

wma_1 = weighted_moving_average(series_non_stationary, 7, [1,1,2,3,5,8,13])
ma_1 = moving_average(series_non_stationary, 7)

with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_non_stationary, color='blue',label='original')
    plt.plot(ma_1, color='red', linewidth='2', label='MA')
    plt.plot(wma_1, color='green', linewidth='2', label='WMA')
    plt.plot(ema_1, color='black', linewidth='3', label='EMA')
    plt.legend()

# %%
alphas = [0.05,0.1,0.3,0.8]
colors = ['red', 'green', 'purple', 'black']
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_non_stationary, color='blue',label='original')
    for i in range(len(alphas)):
        ser = exponential_moving_average(series_non_stationary, alphas[i], n_preds)
        plt.plot(ser, color=colors[i], linewidth='2', label='EMA {}'.format(alphas[i]))
    plt.legend()

# %% [markdown]
# #### Для стационарного ряда

# %%
ema_2 = exponential_moving_average(series_stationary, 0.6, n_preds)

wma_2 = weighted_moving_average(series_stationary, 7, [1,1,2,3,5,8,13])
ma_2 = moving_average(series_stationary, 7)

with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_stationary, color='blue',label='original')
    plt.plot(ma_2, color='red', linewidth='2', label='MA')
    plt.plot(wma_2, color='green', linewidth='2', label='WMA')
    plt.plot(ema_2, color='black', linewidth='3', label='EMA')
    plt.legend()

# %%
alphas = [0.05,0.1,0.3,0.8]
colors = ['red', 'green', 'purple', 'black']
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_stationary, color='blue',label='original')
    for i in range(len(alphas)):
        ser = exponential_moving_average(series_stationary, alphas[i], n_preds)
        plt.plot(ser, color=colors[i], linewidth='2', label='EMA {}'.format(alphas[i]))
    plt.legend()

# %% [markdown]
# ## Двойное экспоненциальное сглаживание (DEMA)

# %% [markdown]
# $\hat{y}_t=l_t + s_t$
#
# $\hat{y}_t=\alpha y_t + (1-\alpha)\hat{y}_{t-1}$
#
# $\hat{l}_t = \alpha y_t + (1-\alpha)(l_{t-1} + s_{t-1})$
#
# До сих пор мы рассматривали ряд - как единую составляющую. Но на самом деле, ряд $y_t$ можно представить в виде суммы $l_t$ (уровня) и $s_t$ (тренда). По сути - тренд - это основное направление движения ряда, а уровень - колебание вокруг этого тренда.
#
#
#
#
# Для предсказания уровня мы используем подход на основе классического EMA:
#
# $l_t = \alpha y_t + (1-\alpha)(l_{t-1} + s_{t-1})$
#
# Для прогноза тренда используем так же EMA и простое соображение: историческое значение тренда - это историческое значение тренда, а текущее значение тренда - это изменение уровня. Получим такую формулу:
#
# $s_t = \beta (l_t - l_{t-1}) + (1 - \beta) s_{t-1}$
#
# Итоговый ряд предсказываем по следующей формуле
#
# $\hat{y}_{t+1} = l_t + s_t$

# %%
def double_ema(series, alpha, beta, n_preds):
    result = [series[0]]
    level, trend = series[0], series[1] - series[0]
    for n in range(1, len(series)+n_preds):
        if n < len(series):        
            value = series[n]
            last_level, level = level, alpha*value + (1-alpha)*(level+trend)
            trend = beta*(level-last_level) + (1-beta)*trend
            result.append(level+trend)
        else:
            m = n - len(series)+1
            result.append(level + m*trend)
        
    return pd.Series(result)

# %%
def plot_dema(series, alpha, beta):
    dema = double_ema(series, alpha, beta, n_preds)
    with plt.style.context('bmh'):
        plt.figure(figsize=(14, 8))
        plt.plot(series, color='blue',label='original')
        plt.plot(dema, color='red', linewidth='4', label='DEMA')
        plt.title("alpha={}, beta={}".format(alpha, beta))
        plt.legend()

# %% [markdown]
# #### Для нестационарного ряда

# %%
n_preds = 24
plot_dema(series_non_stationary, 0.2, 0.2)

# %%
alphas = [0.1, 0.6]
betas = [0.1, 0.6]
colors = ['red', 'green', 'purple', 'black']
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_non_stationary, color='blue',label='original')
    for i in range(len(alphas)):
        for j in range(len(betas)):
            ser = dema = double_ema(series_non_stationary, alphas[i], betas[j], n_preds)
            plt.plot(ser, linewidth='2', label=f'EMA alpha {alphas[i]}, beta {betas[j]}')
    plt.legend()

# %% [markdown]
# #### Для стационарного ряда

# %%
plot_dema(series_stationary, 0.2, 0.2)

# %%
alphas = [0.1, 0.6]
betas = [0.1, 0.6]
colors = ['red', 'green', 'purple', 'black']
with plt.style.context('bmh'):
    plt.figure(figsize=(14, 8))
    plt.plot(series_stationary, color='blue',label='original')
    for i in range(len(alphas)):
        for j in range(len(betas)):
            ser = dema = double_ema(series_stationary, alphas[i], betas[j], n_preds)
            plt.plot(ser, linewidth='2', label=f'EMA alpha {alphas[i]}, beta {betas[j]}')
    plt.legend()

# %% [markdown]
# ### Подбор параметров. Кросс-валидация

# %% [markdown]
# #### Для нестационарного ряда

# %%
series = series_non_stationary

train, test, val = series[:80], series[80:100], series[100:]

# %%
def mse(X):
    alpha, beta = X
    result = double_ema(train, alpha, beta, len(test))
    predictions = result[-len(test):]
    error = mean_squared_error(predictions, test)
    return error

# %%
opt = minimize(mse, x0=[0,0], method="L-BFGS-B", bounds = ((0, 1), (0, 1)))

# %%
alpha_opt, beta_opt = opt.x
print(opt)
# Out:
#       fun: 7182.837413848989
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.89408040e+03,  4.36557457e-03])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 39
#       nit: 6
#      njev: 13
#    status: 0
#   success: True
#         x: array([1.        , 0.01867968])

# %%
plot_dema(series=train, alpha=alpha_opt, beta=beta_opt)

# %%
series = series_non_stationary

train, val = series[:80], series[80:]

# %%
def mse_cross_val(X):
    alpha, beta = X
    split = TimeSeriesSplit(n_splits=3) 
    errors = []
    
    for train_split, test_split in split.split(train):
        train_split_ts = train.iloc[train_split]
        test_split_ts = train.iloc[test_split]
#         print(train_split_ts)
#         print(test_split_ts)
        result = double_ema(train_split_ts, alpha, beta, len(test_split))
        predictions = result[-len(test_split_ts):]
        error = mean_squared_error(predictions, test_split_ts)
        errors.append(error)
    print(f'{np.mean(np.array(errors))}------------')
    return np.mean(np.array(errors))

# %%
opt = minimize(mse_cross_val, x0=[0,0], method="Nelder-Mead", bounds = ((0, 1), (0, 1)))
# Out:
# C:\Users\bauhb\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:535: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   warn('Method %s cannot handle constraints nor bounds.' % method,
# 42852.01666666667------------
# 42420.74633545434------------
# 42852.01666666667------------
# 42423.76012425692------------
# 42001.59502263895------------
# 41589.837631057846------------
# 41581.00363623362------------
# 41166.40567746402------------
# 40384.659535371226------------
# 39437.39933333732------------
# 39029.3643031059------------
# 37832.596808953414------------
# 36367.16061008357------------
# 34353.323018051975------------
# 33024.61358646259------------
# 30437.019155819926------------
# 28191.18238394101------------
# 25086.404956897724------------
# 22802.601198760633------------
# 19609.67665582343------------
# 17914.010860103397------------
# 15925.615262193533------------
# 14393.985919737393------------
# 13647.190074035994------------
# ...

# %%
alpha_opt, beta_opt = opt.x
print(opt)
# Out:
#  final_simplex: (array([[0.09351807, 0.18704113],
#        [0.09352631, 0.18700187],
#        [0.09348281, 0.18709059]]), array([970.64039698, 970.64040113, 970.64041255]))
#            fun: 970.6403969781583
#        message: 'Optimization terminated successfully.'
#           nfev: 110
#            nit: 60
#         status: 0
#        success: True
#              x: array([0.09351807, 0.18704113])

# %%
plot_dema(series=train, alpha=alpha_opt, beta=beta_opt)

# %% [markdown]
# #### Для стационарного ряда

# %%
series = pd.Series(series_stationary)

train, test, val = series[:80], series[80:100], series[100:]

# %%
def mse(X):
    alpha, beta = X
    result = double_ema(train, alpha, beta, len(test))
    predictions = result[-len(test):]
    error = mean_squared_error(predictions, test)
    return error

# %%
opt = minimize(mse, x0=[0,0], method="L-BFGS-B", bounds = ((0, 1), (0, 1)))

# %%
alpha_opt, beta_opt = opt.x
print(opt)
# Out:
#       fun: 0.00038668619901859123
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.55609575e-06, -4.99706613e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 102
#       nit: 23
#      njev: 34
#    status: 0
#   success: True
#         x: array([0.10587682, 0.07692775])

# %%
plot_dema(series=train, alpha=alpha_opt, beta=beta_opt)

# %%
series = series_non_stationary

train, val = series[:80], series[80:]

# %%
def mse_cross_val(X):
    alpha, beta = X
    split = TimeSeriesSplit(n_splits=3) 
    errors = []
    
    for train_split, test_split in split.split(train):
        train_split_ts = train.iloc[train_split]
        test_split_ts = train.iloc[test_split]
#         print(train_split_ts)
#         print(test_split_ts)
        result = double_ema(train_split_ts, alpha, beta, len(test_split))
        predictions = result[-len(test_split_ts):]
        error = mean_squared_error(predictions, test_split_ts)
        errors.append(error)
    print(f'{np.mean(np.array(errors))}------------')
    return np.mean(np.array(errors))

# %%
opt = minimize(mse_cross_val, x0=[0,0], method="Nelder-Mead", bounds = ((0, 1), (0, 1)))
# Out:
# C:\Users\bauhb\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:535: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   warn('Method %s cannot handle constraints nor bounds.' % method,
# 42852.01666666667------------
# 42420.74633545434------------
# 42852.01666666667------------
# 42423.76012425692------------
# 42001.59502263895------------
# 41589.837631057846------------
# 41581.00363623362------------
# 41166.40567746402------------
# 40384.659535371226------------
# 39437.39933333732------------
# 39029.3643031059------------
# 37832.596808953414------------
# 36367.16061008357------------
# 34353.323018051975------------
# 33024.61358646259------------
# 30437.019155819926------------
# 28191.18238394101------------
# 25086.404956897724------------
# 22802.601198760633------------
# 19609.67665582343------------
# 17914.010860103397------------
# 15925.615262193533------------
# 14393.985919737393------------
# 13647.190074035994------------
# ...

# %%
alpha_opt, beta_opt = opt.x
print(opt)
# Out:
#  final_simplex: (array([[0.09351807, 0.18704113],
#        [0.09352631, 0.18700187],
#        [0.09348281, 0.18709059]]), array([970.64039698, 970.64040113, 970.64041255]))
#            fun: 970.6403969781583
#        message: 'Optimization terminated successfully.'
#           nfev: 110
#            nit: 60
#         status: 0
#        success: True
#              x: array([0.09351807, 0.18704113])

# %%
plot_dema(series=train, alpha=alpha_opt, beta=beta_opt)

# %% [markdown]
# ## Тройное экспоненциальное сглаживание. Метод Хольта-Винтерса (TEMA)

# %% [markdown]
# Суть метода в том, что начинаем еще учитывать сезонность. Она учитывается в виде третьей компоненты.
#
# **Важно** - метод применим только в случае сезонности. Если ее нет - метод хольта-винтерса не даст хороших результатов;
#
# $l_t = \alpha(y_t - p_{t-\tau}) + (1-\alpha)(l_{t-1} + s_{t-1})$
#
#
# $s_t = \beta(l_t - l_{t-1}) + (1-\beta)s_{t-1}$
#
# $p_t = \gamma(y_t - l_t) + (1-\gamma)p_{t-\tau}$
#
# $\hat{y}_{t+m} = l_x + s_t + p_{t-\tau+1+(m-1)mod\tau}$
#
# Сезонная компонента $p_t$ объясняет повторяющиеся колебания вокруг уровня и тренда; ее параметр - период, после которого начинаются повторения колебаний. Для каждого наблюдения в сезоне формируется своя компонента, например, если длина сезона составляет 3, то мы получим 3 сезонные компоненты.
#
# В уровене из значения ряда теперь вычитается сезонная компонента;
#
# Тренд остаётся без изменений;
#
# Сезонная компонента зависит от текущего значения ряда за вычетом уровня и от предыдущего значения компоненты.
#
# **При сглаживании сезонной компоненты - она сглаживается только со своими измерениями**

# %%
def initial_trend(series, season_len):
    return sum([float(series[i + season_len] - series[i]) / season_len]) / season_len

# %%
def initial_seasonal_components(series, slen):
    seasonals = {}
    season_averages = []
    n_seasons = int(len(series)/slen)
    # compute season averages
    for j in range(n_seasons):
        season_averages.append(sum(series[slen*j:slen*j+slen])/float(slen))
    # compute initial values
    for i in range(slen):
        sum_of_vals_over_avg = 0.0
        for j in range(n_seasons):
            sum_of_vals_over_avg += series[slen*j+i]-season_averages[j]
        seasonals[i] = sum_of_vals_over_avg/n_seasons
    return seasonals

# %%
def triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds):
    result = []
    seasonals = initial_seasonal_components(series, slen)
    for i in range(len(series)+n_preds):
        if i == 0: # initial values
            smooth = series[0]
            trend = initial_trend(series, slen)
            result.append(series[0])
            continue
        if i >= len(series): # we are forecasting
            m = i - len(series) + 1
            result.append((smooth + m*trend) + seasonals[i%slen])
        else:
            val = series[i]
            last_smooth, smooth = smooth, alpha*(val-seasonals[i%slen]) + (1-alpha)*(smooth+trend)
            trend = beta * (smooth-last_smooth) + (1-beta)*trend
            seasonals[i%slen] = gamma*(val-smooth) + (1-gamma)*seasonals[i%slen]
            result.append(smooth+trend+seasonals[i%slen])
    return result

# %%
def plot_tema(alpha, beta, gamma, series, series_to_plot, n_preds=24):
    tema = triple_exponential_smoothing(series, slen, alpha, beta, gamma, n_preds)
    with plt.style.context('bmh'):
        plt.figure(figsize=(14, 8))
        plt.plot(series_to_plot, color='blue',label='original')
        plt.plot(tema, color='red', linewidth='2', label='TEMA')
        plt.title("alpha={}, beta={}, gamma={}".format(alpha, beta, gamma))
        plt.legend()

# %% [markdown]
# #### Для нестационарного ряда

# %%
slen = 12
plot_tema(0.1, 0.1, 0.2, series_non_stationary, series_non_stationary)

# %% [markdown]
# #### Для стационарного ряда

# %%
slen = 12
plot_tema(0.1, 0.1, 0.2, series_stationary, series_stationary)

# %% [markdown]
# ## Подбор параметров

# %% [markdown]
# Для оценки модели, т.е. какая модель лучше всего приближает исходные данные, минимизируется некоторая функция ошибки. Используем стандарнтый RMSE:
#
# $RMSE =  \sqrt {1/n \sum^N_{i=1} (\hat{y}_i - y_i)^2}$
#
# Алгоритм поиска стандартный - метод градиентного спуска. Считаем производные по каждому из параметров и спускаемся в сторону минимума.

# %% [markdown]
# #### Для нестационарного ряда

# %%
len(series_non_stationary)
# Out:
# 144

# %%
series = series_non_stationary

train, test, val = series[:80], series[80:100], series[100:]

# %%
def mse(X):
    alpha, beta, gamma = X
    result = triple_exponential_smoothing(train, 12, alpha, beta, gamma, len(test))
    predictions = result[-len(test):]
    error = mean_squared_error(predictions, test)
    return error

# %%
opt = minimize(mse, x0=[0,0,0], method="L-BFGS-B", bounds = ((0, 1), (0, 1), (0, 1)))

# %%
alpha_opt, beta_opt, gamma_opt = opt.x
print(opt)
# Out:
#       fun: 608.8995930120021
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.60418869e+02,  1.29602995e-02, -0.00000000e+00])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 56
#       nit: 8
#      njev: 14
#    status: 0
#   success: True
#         x: array([1.        , 0.01157378, 1.        ])

# %%
plot_tema(alpha_opt, beta_opt, gamma_opt, series=train, series_to_plot=series[:100], n_preds=len(test))

# %%
plot_tema(alpha_opt, beta_opt, gamma_opt, series=series[:100], series_to_plot=series, n_preds=len(val))

# %% [markdown]
# #### Для стационарного ряда

# %%
len(series_stationary)
# Out:
# 131

# %%
series = series_stationary

train, test, val = series[:80], series[80:100], series[100:]

# %%
def mse(X):
    alpha, beta, gamma = X
    result = triple_exponential_smoothing(train, 12, alpha, beta, gamma, len(test))
    predictions = result[-len(test):]
    error = mean_squared_error(predictions, test)
    return error

# %%
opt = minimize(mse, x0=[0,0,0], method="L-BFGS-B", bounds = ((0, 1), (0, 1), (0, 1)))

# %%
alpha_opt, beta_opt, gamma_opt = opt.x
print(opt)
# Out:
#       fun: 0.0003930800797262694
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([1.74970710e-04, 6.15516427e-05, 2.56296070e-05])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 188
#       nit: 29
#      njev: 47
#    status: 0
#   success: True
#         x: array([0.10729698, 0.08134071, 0.0791067 ])

# %%
plot_tema(alpha_opt, beta_opt, gamma_opt, series=train, series_to_plot=series[:100], n_preds=len(test))

# %%
plot_tema(alpha_opt, beta_opt, gamma_opt, series=series[:100], series_to_plot=series, n_preds=len(val))

# %% [markdown]
# ## Кросс-валидация.

# %% [markdown]
# Проблема кросс-валидации на временных рядах состоит в том, что случайно перемешивать в фолдах значения всего ряда нельзя. Т.к. он имеет временную структуру, и ее надо сохранять (иначе потеряются все взаимосвязи наблюдений);
#
# Будем делать кросс-валидацию на скользящем окне.
#
# Суть достаточно проста:
# 1. Берем t измерений
# 2. Делаем прогноз на n измерений вперед и считаем ошибку
# 3. Берем t+n измерений
# 4. Делаем прогноз на n измерений вперед и считаем ошибку
# 5. Берем t+2*n измерений
# 6. Делаем прогноз на n измерений вперед и считаем ошибку
# ...

# %% [markdown]
# #### Для нестационарного ряда

# %%
series = series_non_stationary

train, val = series[:80], series[80:]

# %%
len(series)
# Out:
# 144

# %%
def mse_cross_val(X):
    alpha, beta, gamma = X
    split = TimeSeriesSplit(n_splits=3) 
    errors = []
    
    for train_split, test_split in split.split(train):
        train_split_ts = train.iloc[train_split]
        test_split_ts = train.iloc[test_split]
#         print(train_split_ts)
#         print(test_split_ts)
        result = triple_exponential_smoothing(train_split_ts, 12, alpha, beta, gamma, len(test_split))
        predictions = result[-len(test_split_ts):]
        error = mean_squared_error(predictions, test_split_ts)
        errors.append(error)
    print(f'{np.mean(np.array(errors))}------------')
    return np.mean(np.array(errors))

# %%
opt = minimize(mse_cross_val, x0=[0,0,0], method="Nelder-Mead", bounds = ((0, 1), (0, 1), (0, 1)))
# Out:
# C:\Users\bauhb\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:535: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   warn('Method %s cannot handle constraints nor bounds.' % method,
# 11462.020415637848------------
# 11353.793478180558------------
# 11462.020415637848------------
# 11453.090346835908------------
# 11384.314354482936------------
# 11332.65371708451------------
# 11269.199347184354------------
# 11221.00241547387------------
# 11109.26429995572------------
# 11103.900800296135------------
# 10967.550151233489------------
# 10886.593630450707------------
# 10670.130405374834------------
# 10578.345325987151------------
# 10266.637993968781------------
# 10181.435353988836------------
# 9774.146051664275------------
# 9596.751373645526------------
# 9066.77842866559------------
# 8860.538929498527------------
# 8211.014143266008------------
# 8015.3138102169905------------
# 7346.567883423561------------
# ...

# %%
alpha_opt, beta_opt, gamma_opt = opt.x
print(opt)
# Out:
#  final_simplex: (array([[5.34248102e-04, 2.98173717e+01, 5.30536764e-01],
#        [5.46270446e-04, 2.92011742e+01, 5.33108361e-01],
#        [5.47559435e-04, 2.92206464e+01, 5.29318201e-01],
#        [5.43707264e-04, 2.92455277e+01, 5.32806785e-01]]), array([247.35877755, 247.36181573, 247.36404281, 247.36468982]))
#            fun: 247.35877754603928
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 600
#            nit: 354
#         status: 1
#        success: False
#              x: array([5.34248102e-04, 2.98173717e+01, 5.30536764e-01])

# %%
plot_tema(alpha_opt, beta_opt, gamma_opt, series=series[:80], series_to_plot=series, n_preds=len(val))

# %% [markdown]
# #### Для стационарного ряда

# %%
series = pd.Series(series_stationary)

train, val = series[:80], series[80:]

# %%
series.shape
# Out:
# (131,)

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
def mse_cross_val(X):
    alpha, beta, gamma = X
    split = TimeSeriesSplit(n_splits=3) 
    errors = []
    
    for train_split, test_split in split.split(train):
        train_split_ts = train.iloc[train_split]
        test_split_ts = train.iloc[test_split]
#         print(train_split_ts)
#         print(test_split_ts)
        result = triple_exponential_smoothing(train_split_ts, 12, alpha, beta, gamma, len(test_split))
        predictions = result[-len(test_split_ts):]
        error = mean_squared_error(predictions, test_split_ts)
        errors.append(error)
    print(f'{np.mean(np.array(errors))}------------')
    return np.mean(np.array(errors))

# %%
opt = minimize(mse_cross_val, x0=[0,0,0], method="Nelder-Mead", bounds = ((0, 1), (0, 1), (0, 1)))
# Out:
# C:\Users\bauhb\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:535: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   warn('Method %s cannot handle constraints nor bounds.' % method,
# 0.007077820546070716------------
# 0.00702178520469527------------
# 0.007077820546070746------------
# 0.007073312535293842------------
# 0.007037672690581355------------
# 0.007011055245790124------------
# 0.006978503109011151------------
# 0.0069536835325074734------------
# 0.006896721686041802------------
# 0.006893875132512053------------
# 0.006824741032286301------------
# 0.00678449477554761------------
# 0.006677026210438006------------
# 0.006631321774445603------------
# 0.0064796884918184------------
# 0.0064386025005131785------------
# 0.006246094875863151------------
# 0.006165896764089868------------
# 0.005929474678263898------------
# 0.005836986960259384------------
# 0.005564120553266088------------
# 0.005487073616387048------------
# ...

# %%
alpha_opt, beta_opt, gamma_opt = opt.x
print(opt)
# Out:
#  final_simplex: (array([[ 0.07874829,  0.02027483, -0.02723489],
#        [ 0.07877409,  0.02026979, -0.027197  ],
#        [ 0.07879661,  0.02025385, -0.02725743],
#        [ 0.07880683,  0.02027103, -0.02729201]]), array([0.00357436, 0.00357436, 0.00357437, 0.00357437]))
#            fun: 0.003574364991263544
#        message: 'Optimization terminated successfully.'
#           nfev: 178
#            nit: 99
#         status: 0
#        success: True
#              x: array([ 0.07874829,  0.02027483, -0.02723489])

# %%
plot_tema(alpha_opt, beta_opt, gamma_opt, series=series[:80], series_to_plot=series, n_preds=len(val))

# %% [markdown]
# ## Вывод

# %% [markdown]
# #### Тройное экспоненциальное сглаживание лучше других моделей приближает ряд и позволяет сделать прогноз на заданный временной интервал.
