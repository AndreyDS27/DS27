# %% [markdown]
# # Домашнее задание "Математический анализ. Производная"

# %% [markdown]
# ## Уровень 0:¶
#
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.
#
# ## Уровень 1:
#
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %% [markdown]
# ## Уровень 0:
#
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.

# %%
# Импорт derivative из scipy.misc для расчета производной
from scipy.misc import derivative

# Импорт библиотеки sympy для выполнения символьных вычислений
from sympy import *
x = symbols('x')

# %% [markdown]
# #### Использование sympy.diff() для нахождения производной

# %%
# Формула 1-й производной c sympy.diff()
dif_1 = diff(𝑥**5+4*𝑠𝑖𝑛(2*𝑥)+𝑐𝑜𝑠(3*𝑥+3), x)
dif_1
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)

# %%
# Значение 1-й производной в x = 1.0
dif_1.evalf(subs={'x':1})
# Out:
# 2.50907180221964

# %%
# Формула 2-й производной c sympy.diff()
dif_2 = diff(dif_1, x)
dif_2
# Out:
# 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3)

# %%
# Значение 2-й производной в x = 1.0
dif_2.evalf(subs={'x':1})
# Out:
# -3.19029140906420

# %% [markdown]
# #### Использование scipy.misc derivative для нахождения производной

# %%
# Использование scipy.misc для нахождения производной

'''Отдает функцию, производную которой нужно найти'''
def f(x):
    return 𝑥**5+4*𝑠𝑖𝑛(2*𝑥)+𝑐𝑜𝑠(3*𝑥+3)

# %%
# Формула 1-й производной
derivative(f, x, n=1)
# Out:
# -0.5*(x - 1.0)**5 + 0.5*(x + 1.0)**5 - 2.0*sin(2*x - 2.0) + 2.0*sin(2*x + 2.0) - 0.5*cos(3*x) + 0.5*cos(3*x + 6.0)

# %%
# Значение 1-й производной в x = 1.0
x1 = 1.0
derivative(f, x1, n=1, dx=1e-6)
# Out:
# 2.50907180188165

# %%
# Формула 2-й производной
derivative(f, x, n=2)
# Out:
# -2.0*x**5 + 1.0*(x - 1.0)**5 + 1.0*(x + 1.0)**5 - 8.0*sin(2*x) + 4.0*sin(2*x - 2.0) + 4.0*sin(2*x + 2.0) + 1.0*cos(3*x) - 2.0*cos(3*x + 3) + 1.0*cos(3*x + 6.0)

# %%
# Значение 2-й производной в x = 1.0
x2 = 1.0
derivative(f, x2, n=2, dx=1e-6)
# Out:
# -3.19033688356285

# %% [markdown]
# ***Символьные выражения производных в методах sympy.diff() и scipy.misc derivative отличаются, но вычисления результата в точке x=1 идентичны.***

# %% [markdown]
# ## Уровень 1:
#
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### С использованием scipy.misc derivative для нахождения производной

# %%
# с использованием scipy.misc derivative

# интервал x [-5; 5]
x = np.linspace(-5, 5, num=200, endpoint=True)   

'''Отдает функцию, производную которой нужно найти'''
def f(x):
    return np.sin(2*x+1)**5

fx = f(x)                                             # исходная функция
f1x = [derivative(f, xx, dx=1e-6, n=1) for xx in x]   # 1-я производная
f2x = [derivative(f, xx, dx=1e-6, n=2) for xx in x]   # 2-я производная

# построение графиков
plt.figure(figsize=(10, 10))
plt.plot(x, fx, label = 'function')
plt.plot(x, f1x, label = 'f1x')
plt.plot(x, f2x, label = 'f2x')
plt.legend()
plt.title('$f(x) = sin^5(2x+1)$, 1st and 2nd derivative  plots')
# Out:
# Text(0.5, 1.0, '$f(x) = sin^5(2x+1)$, 1st and 2nd derivative  plots')
